# %% [markdown]
# <a href="https://colab.research.google.com/github/Rushil-K/BDMA/blob/main/Projects1%2B2/Project2/nmrk2627_HMS_MySQL_Report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Hospital Management System**
# ## **Project Report**
# Submitted By:
# - Rushil Kohli (055027)
# - Navneet Mittal (055026)

# %% [markdown]
# ## **1\. Introduction**
#
# The **Hospital Management System (HMS)** is designed to streamline hospital operations by managing **patient records, doctor information, appointments, and room availability**. The system is implemented using **MySQL**, ensuring a **structured, secure, and efficient** approach to data management.
#
# This report covers **database schema creation, querying, business insights, stress testing, normalization**, and **visualizations** to extract key trends and improve hospital administration.

# %% [markdown]
# ## **2. Detailed Features of the Tables**
#
# ### Key Features
# - **Patient Management**: Comprehensive patient records including demographics, medical history, and billing information.
# - **Doctor and Appointment Scheduling**: Efficient tracking of doctors, their specializations, and patient appointments.
# - **Medical Diagnosis and Treatment Records**: Storage of medical diagnoses, treatments, prescriptions, and test results.
# - **Billing and Payment Management**: Tracks financial transactions for services rendered.
# - **Hospital Staff and Department Management**: Storage of doctor and staff details, including roles and salaries.
# - **Room and Admission Management**: Assignment of hospital rooms and management of patient admissions.
# - **Laboratory and Pharmacy Management**: Tracking of lab tests, reports, medicines, and inventory.
# - **Security and Access Control**: Implementation of role-based access control (RBAC) to protect sensitive patient data.
# - **Scalability**: Database structure designed to accommodate future expansion of hospital operations and increased patient records.
#
# ## Table Descriptions & Attributes
#
# ### 1. Patients
# Stores patient personal details and medical information.
#
# ### 2. Patient_Addresses
# Manages patient address details.
#
# ### 3. Doctors
# Stores doctor details, including specialization and experience.
#
# ### 4. Appointments
# Records patient-doctor appointments.
#
# ### 5. Medical_Records
# Maintains patient medical history.
#
# ### 6. Diagnosis
# Stores patient diagnoses and prescriptions.
#
# ### 7. Billing
# Handles patient billing and payment tracking.
#
# ### 8. Payment_Details
# Stores details of patient payments.
#
# ### 9. Staff
# Manages hospital staff information, including roles and salaries.
#
# ### 10. Rooms
# Keeps track of room occupancy and availability.
#
# ### 11. Admissions
# Maintains records of patient admissions and discharges.
#
# ### 12. Inventory
# Manages hospital equipment and medical supplies.
#
# ### 13. Suppliers
# Stores details of suppliers providing medical supplies.
#
# ### 14. Tests
# Lists diagnostic tests conducted in the hospital.
#
# ### 15. Lab_Reports
# Maintains laboratory test reports.
#
# ### 16. Test_Results
# Stores results of diagnostic tests.
#
# ### 17. Pharmacy
# Manages medicine inventory.
#
# ### 18. Stock
# Tracks pharmacy stock, including quantity and expiry dates.

# %% [markdown]
# ## Detailed Features of the Tables
#
# To provide a more visually appealing representation, each table's details will be presented in a structured format with clear headings and formatting.
#
# ---
#
# ### 1. Patients
#
# **Description:** Stores patient personal details.
#
# | Attribute         | Data Type     | Constraints                     | Description                               |
# |-------------------|---------------|---------------------------------|-------------------------------------------|
# | `Patient_ID`      | INT           | PRIMARY KEY, NOT NULL           | Unique identifier for the patient         |
# | `First_Name`    | VARCHAR(50)   | NOT NULL                        | Patient's first name                      |
# | `Last_Name`     | VARCHAR(50)   | NOT NULL                        | Patient's last name                       |
# | `DOB`             | DATE          | NOT NULL                        | Patient's date of birth                   |
# | `Gender`          | CHAR(1)       | NOT NULL                        | Patient's gender (e.g., M/F)            |
# | `Contact_Number`  | VARCHAR(15)   | NOT NULL                        | Patient's contact phone number            |
# | `Email`           | VARCHAR(100)  | NULL                            | Patient's email address                   |
# | `Blood_Type`      | VARCHAR(3)    | NULL                            | Patient's blood type                      |
# | `Insurance_Provider`| VARCHAR(100)  | NULL                            | Patient's insurance provider name         |
# | `Insurance_Number`| VARCHAR(50)   | NULL                            | Patient's insurance policy number         |
#
# ---
#
# ### 2. Patient_Addresses
#
# **Description:** Stores addresses of patients.
#
# | Attribute      | Data Type     | Constraints             | Description                       |
# |----------------|---------------|-------------------------|-----------------------------------|
# | `Address_ID`   | INT           | PRIMARY KEY, NOT NULL   | Unique identifier for the address   |
# | `Patient_ID`   | INT           | FOREIGN KEY, NOT NULL   | Foreign key referencing `Patients` |
# | `Address_Line1`| VARCHAR(255)  | NOT NULL                | First line of the patient's address |
# | `Address_Line2`| VARCHAR(255)  | NULL                    | Second line of the patient's address|
# | `City`         | VARCHAR(100)  | NOT NULL                | City of the patient's address     |
# | `State`        | VARCHAR(100)  | NOT NULL                | State of the patient's address    |
# | `ZIP_Code`     | VARCHAR(10)   | NOT NULL                | ZIP code of the patient's address |
#
# ---
#
# ### 3. Doctors
#
# **Description:** Stores doctor details.
#
# | Attribute         | Data Type     | Constraints             | Description                        |
# |-------------------|---------------|-------------------------|------------------------------------|
# | `Doctor_ID`       | INT           | PRIMARY KEY, NOT NULL   | Unique identifier for the doctor    |
# | `First_Name`    | VARCHAR(50)   | NOT NULL                | Doctor's first name                 |
# | `Last_Name`     | VARCHAR(50)   | NOT NULL                | Doctor's last name                  |
# | `Specialization`  | VARCHAR(100)  | NOT NULL                | Doctor's medical specialization     |
# | `Contact_Number`  | VARCHAR(15)   | NOT NULL                | Doctor's contact phone number       |
# | `Email`           | VARCHAR(100)  | NOT NULL                | Doctor's email address              |
# | `Experience_Years`| INT           | NOT NULL                | Doctor's years of experience        |
# | `Department_ID`   | INT           | NULL                    | Foreign key referencing a `Department` table (if exists) |
#
# ---
#
# ### 4. Appointments
#
# **Description:** Stores appointment details between patients and doctors.
#
# | Attribute         | Data Type | Constraints             | Description                           |
# |-------------------|-----------|-------------------------|---------------------------------------|
# | `Appointment_ID`  | INT       | PRIMARY KEY, NOT NULL   | Unique identifier for the appointment   |
# | `Patient_ID`      | INT       | FOREIGN KEY, NOT NULL   | Foreign key referencing `Patients`    |
# | `Doctor_ID`       | INT       | FOREIGN KEY, NOT NULL   | Foreign key referencing `Doctors`     |
# | `Appointment_Date`| DATE      | NOT NULL                | Date of the appointment               |
# | `Appointment_Time`| TIME      | NOT NULL                | Time of the appointment               |
# | `Status`          | VARCHAR(50)| NOT NULL                | Status of the appointment (e.g., Scheduled, Completed, Cancelled) |
# | `Reason`          | VARCHAR(255)| NULL                    | Reason for the appointment              |
#
# ---
#
# ### 5. Medical_Records
#
# **Description:** Stores patient medical records.
#
# | Attribute    | Data Type | Constraints             | Description                               |
# |--------------|-----------|-------------------------|-------------------------------------------|
# | `Record_ID`  | INT       | PRIMARY KEY, NOT NULL   | Unique identifier for the medical record  |
# | `Patient_ID` | INT       | FOREIGN KEY, NOT NULL   | Foreign key referencing `Patients`        |
# | `Doctor_ID`  | INT       | FOREIGN KEY, NOT NULL   | Foreign key referencing `Doctors`         |
# | `Record_Date`| DATE      | NOT NULL                | Date when the medical record was created |
#
# ---
#
# ### 6. Diagnosis
#
# **Description:** Stores diagnoses and prescriptions related to medical records.
#
# | Attribute       | Data Type | Constraints             | Description                                  |
# |-----------------|-----------|-------------------------|----------------------------------------------|
# | `Diagnosis_ID`  | INT       | PRIMARY KEY, NOT NULL   | Unique identifier for the diagnosis          |
# | `Record_ID`     | INT       | FOREIGN KEY, NOT NULL   | Foreign key referencing `Medical_Records`    |
# | `Diagnosis_Details`| TEXT      | NOT NULL                | Detailed description of the diagnosis        |
# | `Prescription`  | TEXT      | NULL                    | Any prescriptions given to the patient       |
#
# ---
#
# ### 7. Billing
#
# **Description:** Stores patient billing details.
#
# | Attribute      | Data Type      | Constraints             | Description                               |
# |----------------|----------------|-------------------------|-------------------------------------------|
# | `Bill_ID`      | INT            | PRIMARY KEY, NOT NULL   | Unique identifier for the bill            |
# | `Patient_ID`   | INT            | FOREIGN KEY, NOT NULL   | Foreign key referencing `Patients`        |
# | `Total_Amount` | DECIMAL(10,2)  | NOT NULL                | Total amount due on the bill              |
# | `Bill_Date`    | DATE           | NOT NULL                | Date when the bill was generated          |
# | `Payment_Status`| VARCHAR(50)    | NOT NULL                | Status of the payment (e.g., Paid, Pending) |
#
# ---
#
# ### 8. Payment_Details
#
# **Description:** Stores payment transactions.
#
# | Attribute      | Data Type      | Constraints             | Description                               |
# |----------------|----------------|-------------------------|-------------------------------------------|
# | `Payment_ID`   | INT            | PRIMARY KEY, NOT NULL   | Unique identifier for the payment         |
# | `Bill_ID`      | INT            | FOREIGN KEY, NOT NULL   | Foreign key referencing `Billing`         |
# | `Amount_Paid`  | DECIMAL(10,2)  | NOT NULL                | Amount paid in this transaction           |
# | `Payment_Date` | DATE           | NOT NULL                | Date when the payment was made            |
# | `Payment_Mode` | VARCHAR(50)    | NOT NULL                | Method of payment (e.g., Credit Card, Cash)|
#
# ---
#
# ### 9. Staff
#
# **Description:** Stores hospital staff details.
#
# | Attribute         | Data Type      | Constraints             | Description                             |
# |-------------------|----------------|-------------------------|-----------------------------------------|
# | `Staff_ID`        | INT            | PRIMARY KEY, NOT NULL   | Unique identifier for the staff member    |
# | `First_Name`    | VARCHAR(50)    | NOT NULL                | Staff member's first name               |
# | `Last_Name`     | VARCHAR(50)    | NOT NULL                | Staff member's last name                |
# | `Role`            | VARCHAR(100)   | NOT NULL                | Staff member's job role                 |
# | `Contact_Number`  | VARCHAR(15)    | NOT NULL                | Staff member's contact phone number     |
# | `Email`           | VARCHAR(100)   | NULL                    | Staff member's email address            |
# | `Department_ID`   | INT            | NULL                    | Foreign key referencing a `Department` table (if exists) |
# | `Salary`          | DECIMAL(10,2)  | NOT NULL                | Staff member's salary                   |
# | `Shift_Timings`   | VARCHAR(50)    | NOT NULL                | Staff member's work shift timings       |
#
# ---
#
# ### 10. Rooms
#
# **Description:** Stores room information.
#
# | Attribute       | Data Type   | Constraints             | Description                        |
# |-----------------|-------------|-------------------------|------------------------------------|
# | `Room_ID`       | INT         | PRIMARY KEY, NOT NULL   | Unique identifier for the room       |
# | `Room_Type`     | VARCHAR(50) | NOT NULL                | Type of room (e.g., Single, Double) |
# | `Capacity`      | INT         | NOT NULL                | Maximum capacity of the room       |
# | `Occupied_Status`| VARCHAR(50)| NOT NULL                | Current occupancy status (e.g., Vacant, Occupied) |
#
# ---
#
# ### 11. Admissions
#
# **Description:** Stores patient admission records.
#
# | Attribute      | Data Type | Constraints             | Description                                 |
# |----------------|-----------|-------------------------|---------------------------------------------|
# | `Admission_ID` | INT       | PRIMARY KEY, NOT NULL   | Unique identifier for the admission         |
# | `Patient_ID`   | INT       | FOREIGN KEY, NOT NULL   | Foreign key referencing `Patients`          |
# | `Room_ID`      | INT       | FOREIGN KEY, NOT NULL   | Foreign key referencing `Rooms`             |
# | `Admission_Date`| DATE      | NOT NULL                | Date of patient admission                   |
# | `Discharge_Date`| DATE      | NULL                    | Date of patient discharge                   |
# | `Diagnosis`    | TEXT      | NOT NULL                | Initial diagnosis upon admission            |
#
# ---
#
# ### 12. Inventory
#
# **Description:** Stores inventory details.
#
# | Attribute    | Data Type     | Constraints             | Description                             |
# |--------------|---------------|-------------------------|-----------------------------------------|
# | `Item_ID`    | INT           | PRIMARY KEY, NOT NULL   | Unique identifier for the inventory item|
# | `Item_Name`  | VARCHAR(100)  | NOT NULL                | Name of the inventory item              |
# | `Category`   | VARCHAR(100)  | NOT NULL                | Category of the inventory item          |
# | `Quantity`   | INT           | NOT NULL                | Current quantity in stock               |
# | `Supplier_ID`| INT           | FOREIGN KEY, NOT NULL   | Foreign key referencing `Suppliers`       |
# | `Purchase_Date`| DATE          | NOT NULL                | Date when the item was purchased         |
#
# ---
#
# ### 13. Suppliers
#
# **Description:** Stores supplier details.
#
# | Attribute         | Data Type     | Constraints             | Description                               |
# |-------------------|---------------|-------------------------|-------------------------------------------|
# | `Supplier_ID`     | INT           | PRIMARY KEY, NOT NULL   | Unique identifier for the supplier        |
# | `Supplier_Name`   | VARCHAR(100)  | NOT NULL                | Name of the supplier                      |
# | `Contact_Number`  | VARCHAR(15)   | NULL                    | Supplier's contact phone number           |
# | `Email`           | VARCHAR(100)  | NULL                    | Supplier's email address                  |
# | `Address`         | TEXT          | NULL                    | Supplier's address                        |
# | `Category_Provided`| VARCHAR(100)  | NOT NULL                | Categories of items provided by the supplier |
#
# ---
#
# ### 14. Tests
#
# **Description:** Stores diagnostic test details.
#
# | Attribute     | Data Type      | Constraints             | Description                           |
# |---------------|----------------|-------------------------|---------------------------------------|
# | `Test_ID`     | INT            | PRIMARY KEY, NOT NULL   | Unique identifier for the test          |
# | `Test_Name`   | VARCHAR(100)   | NOT NULL                | Name of the diagnostic test             |
# | `Description` | TEXT           | NULL                    | Description of the test               |
# | `Price`       | DECIMAL(10,2)  | NOT NULL                | Price of the test                       |
#
# ---
#
# ### 15. Lab_Reports
#
# **Description:** Stores lab reports for patients.
#
# | Attribute    | Data Type | Constraints             | Description                               |
# |--------------|-----------|-------------------------|-------------------------------------------|
# | `Report_ID`  | INT       | PRIMARY KEY, NOT NULL   | Unique identifier for the lab report      |
# | `Patient_ID` | INT       | FOREIGN KEY, NOT NULL   | Foreign key referencing `Patients`        |
# | `Doctor_ID`  | INT       | FOREIGN KEY, NOT NULL   | Foreign key referencing `Doctors`         |
# | `Report_Date`| DATE      | NOT NULL                | Date when the lab report was generated   |
#
# ---
#
# ### 16. Test_Results
#
# **Description:** Stores results of medical tests.
#
# | Attribute    | Data Type | Constraints             | Description                               |
# |--------------|-----------|-------------------------|-------------------------------------------|
# | `Result_ID`  | INT       | PRIMARY KEY, NOT NULL   | Unique identifier for the test result     |
# | `Report_ID`  | INT       | FOREIGN KEY, NOT NULL   | Foreign key referencing `Lab_Reports`     |
# | `Test_ID`    | INT       | FOREIGN KEY, NOT NULL   | Foreign key referencing `Tests`           |
# | `Results`    | TEXT      | NOT NULL                | Results of the diagnostic test            |
#
# ---
#
# ### 17. Pharmacy
#
# **Description:** Stores medicine information.
#
# | Attribute      | Data Type      | Constraints             | Description                             |
# |----------------|----------------|-------------------------|-----------------------------------------|
# | `Medicine_ID`  | INT            | PRIMARY KEY, NOT NULL   | Unique identifier for the medicine        |
# | `Medicine_Name`| VARCHAR(100)   | NOT NULL                | Name of the medicine                    |
# | `Category`     | VARCHAR(100)   | NOT NULL                | Category of the medicine                |
# | `Price`        | DECIMAL(10,2)  | NOT NULL                | Price of the medicine                   |
#
# ---
#
# ### 18. Stock
#
# **Description:** Stores stock details of medicines.
#
# | Attribute         | Data Type | Constraints             | Description                               |
# |-------------------|-----------|-------------------------|-------------------------------------------|
# | `Stock_ID`        | INT       | PRIMARY KEY, NOT NULL   | Unique identifier for the stock entry     |
# | `Medicine_ID`     | INT       | FOREIGN KEY, NOT NULL   | Foreign key referencing `Pharmacy`        |
# | `Quantity_Available`| INT       | NOT NULL                | Current quantity of the medicine in stock |
# | `Expiry_Date`     | DATE      | NOT NULL                | Expiration date of the medicine batch     |
#
# ---
#
# **THE RELATIONSHIP DESCRIPTIONS ARE AS FOLLOWS:**
#
# For enhanced readability, the relationships are presented in a list format with clear indicators of the relationship type and cardinality.
#
# 1.  **Patients** and **Patient\_Addresses**
#     -   **Type:** One-to-Many
#     -   **Cardinality:**
#         -   **Patients:** 1 (Each patient must have at least one address)
#         -   **Patient\_Addresses:** 1..\* (A patient can have multiple addresses)
#
# 2.  **Patients** and **Appointments**
#     -   **Type:** One-to-Many
#     -   **Cardinality:**
#         -   **Patients:** 1 (A patient can have multiple appointments)
#         -   **Appointments:** 0..\* (An appointment belongs to one patient)
#
# 3.  **Doctors** and **Appointments**
#     -   **Type:** One-to-Many
#     -   **Cardinality:**
#         -   **Doctors:** 1 (A doctor can have multiple appointments)
#         -   **Appointments:** 0..\* (An appointment is with one doctor)
#
# 4.  **Patients** and **Medical\_Records**
#     -   **Type:** One-to-Many
#     -   **Cardinality:**
#         -   **Patients:** 1 (A patient can have multiple medical records)
#         -   **Medical\_Records:** 0..\* (A medical record belongs to one patient)
#
# 5.  **Doctors** and **Medical\_Records**
#     -   **Type:** One-to-Many
#     -   **Cardinality:**
#         -   **Doctors:** 1 (A doctor can create multiple medical records)
#         -   **Medical\_Records:** 0..\* (A medical record is associated with one doctor)
#
# 6.  **Medical\_Records** and **Diagnosis**
#     -   **Type:** One-to-One
#     -   **Cardinality:**
#         -   **Medical\_Records:** 1 (Each medical record has one diagnosis)
#         -   **Diagnosis:** 1 (Each diagnosis belongs to one medical record)
#
# 7.  **Patients** and **Billing**
#     -   **Type:** One-to-Many
#     -   **Cardinality:**
#         -   **Patients:** 1 (A patient can have multiple bills)
#         -   **Billing:** 0..\* (A bill belongs to one patient)
#
# 8.  **Billing** and **Payment\_Details**
#     -   **Type:** One-to-Many
#     -   **Cardinality:**
#         -   **Billing:** 1 (A bill can have multiple payment details)
#         -   **Payment\_Details-   **Payment\_Details:** 0..\* (A payment detail is associated with one bill)
#
# 9.  **Patients** and **Admissions**
#     -   **Type:** One-to-Many
#     -   **Cardinality:**
#         -   **Patients:** 1 (A patient can have multiple admissions)
#         -   **Admissions:** 0..\* (An admission belongs to one patient)
#
# 10. **Rooms** and **Admissions**
#     -   **Type:** One-to-Many
#     -   **Cardinality:**
#         -   **Rooms:** 1 (A room can have multiple admissions over time)
#         -   **Admissions:** 0..\* (An admission utilizes one room)
#
# 11. **Inventory** and **Suppliers**
#     -   **Type:** Many-to-One
#     -   **Cardinality:**
#         -   **Inventory:** 1..\* (Each inventory item has one supplier)
#         -   **Suppliers:** 1 (A supplier can provide multiple inventory items)
#
# 12. **Patients** and **Lab\_Reports**
#     -   **Type:** One-to-Many
#     -   **Cardinality:**
#         -   **Patients:** 1 (A patient can have multiple lab reports)
#         -   **Lab\_Reports:** 0..\* (A lab report belongs to one patient)
#
# 13. **Doctors** and **Lab\_Reports**
#     -   **Type:** One-to-Many
#     -   **Cardinality:**
#         -   **Doctors:** 1 (A doctor can be associated with multiple lab reports)
#         -   **Lab\_Reports:** 0..\* (A lab report is associated with one doctor)
#
# 14. **Lab\_Reports** and **Test\_Results**
#     -   **Type:** One-to-Many
#     -   **Cardinality:**
#         -   **Lab\_Reports:** 1 (Each lab report can have multiple test results)
#         -   **Test\_Results:** 0..\* (A test result belongs to one lab report)
#
# 15. **Tests** and **Test\_Results**
#     -   **Type:** One-to-Many
#     -   **Cardinality:**
#         -   **Tests:** 1 (A test can have multiple test results across different reports)
#         -   **Test\_Results:** 0..\* (A test result is for one specific test)
#
# 16. **Pharmacy** and **Stock**
#     -   **Type:** One-to-Many
#     -   **Cardinality:**
#         -   **Pharmacy:** 1 (A medicine can have multiple stock entries for different batches/expiry dates)
#         -   **Stock:** 0..\* (A stock entry is for one specific medicine)

# %% [markdown]
# ## **ERD**

# %% [markdown]
# ![{1FCF7D43-EFB2-4278-89B7-F02F4DBDEFE9}.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# ### **SQL Schema Creation**
#
# SQL for creating the **Patients table**:
#
#
# * `CREATE TABLE Patients (`
# *     `Patient_ID INT PRIMARY KEY,`
# *     `First_Name VARCHAR(50),`
# *     `Last_Name VARCHAR(50),`
# *     `DOB DATE,`
# *     `Gender CHAR(1),`
# *     `Contact_Number VARCHAR(15),`
# *     `Email VARCHAR(100),`
# *     `Blood_Type VARCHAR(3),`
# *     `Insurance_Provider VARCHAR(100),`
# *     `Insurance_Number VARCHAR(50)`
# * `);`
#
#
# This ensures **uniqueness (Patient\_ID as primary key)** and **structured data storage**.
#
# ---
#
# ## **3\. Querying & Data Retrieval**
#
# The database allows efficient querying to extract critical hospital information:
#
# ### **Queries & Their Business Utility**
#
# #### **1\. Retrieve All Patients**
#
#
#
# * `SELECT * FROM Patients;`
#
#
#  **Insight**: Helps hospital administrators view all registered patients.
#
# #### **2\. Get All Doctors & Specializations**
#
#
#
# * `SELECT First_Name, Last_Name, Specialization FROM Doctors;`
#
#
#  **Insight**: Identifies available doctors based on specialization for better scheduling.
#
# #### **3\. Find Appointments for a Specific Date**
#
#
#
# * `SELECT * FROM Appointments WHERE Appointment_Date = '2024-02-16';`
#
#
# **Insight**: Assists in daily workload planning and patient management.
#
# #### **4\. Check Room Availability**
#
#
#
# * `SELECT * FROM Rooms WHERE Occupied_Status = 'Occupied';`
#
#
# **Insight**: Prevents overbooking and allows for better space management.
#
# #### **5\. Retrieve Patient Details with Address**
#
#
#
# * `SELECT P.Patient_ID, P.First_Name, P.Last_Name, A.Address_Line1, A.City, A.State`
# * `FROM Patients P`
# * `JOIN Patient_Addresses A ON P.Patient_ID = A.Patient_ID;`
#
#
# **Insight**: Helps in emergency responses by accessing patient locations.
#
# ---
#
# ## **4\. Business Insights & Inferences**
#
# The database provides key insights that can drive decision-making for hospital management:
#
# ### **A. Patient Demographics & Insurance Coverage**
#
# * **Majority Gender:** **67% Male**, **33% Female**.
# * **Blood Type Trends:** Diverse distribution aids in planning blood bank resources.
# * **Insurance Coverage:** Most patients are covered by **Max Bupa, HDFC Ergo, and Apollo Munich**, indicating preferred providers.
#
# ### **B. Appointment & Doctor Scheduling Optimization**
#
# * Peak appointment times help adjust **doctor availability**.
# * Most booked specializations indicate **demand for specific healthcare services**.
#
# ### **C. Room & Resource Allocation**
#
# * Monitoring **room occupancy** prevents overbooking.
# * Trends in **discharge rates** can predict **resource needs**.
#
# ---
#
# ## **5\. Data Visualizations**
#
# ### **1\. Patient Gender Distribution**
#
# ![][image1]
#
# * Shows the proportion of male and female patients.
#
# ### **2\. Blood Type Distribution**
#
# ![][image2]
#
# * Helps in managing blood bank inventory.
#
# ### **3\. Insurance Provider Statistics**
#
# ![][image3]
#
# * Identifies most used insurance providers.
#
# ---
#
# ## **6\. Stress Testing & Performance Analysis**
#
# ### **A. What is Stress Testing?**
#
# * Evaluates **database efficiency** under heavy load conditions.
# * Ensures **queries execute quickly without delays**.
#
# ### **B. SQL-Based Stress Testing (First Normal Form \- 1NF)**
#
# To ensure **atomicity (1NF compliance)**, a query was run to check **multi-valued attributes**:
#
#
#
# * `SELECT * FROM Patients`
# * `WHERE Contact_Number LIKE '%,%';`
#
#
# **Findings**: No multi-valued attributes detected → **1NF achieved**.
#
# ### **C. Performance Optimization Techniques**
#
# * **Indexing:** Used for quick search in large tables.
# * **Query Optimization:** SELECT statements refined for efficiency.
# * **Load Balancing:** Ensuring queries execute smoothly under heavy usage.
#
# ---
#
#
# ## **7\. Normalization & Database Optimization**
#
# ### **A. What is Normalization?**
#
# * **1NF:** Ensures atomic values (no repeating columns).
# * **2NF:** Eliminates partial dependencies.
# * **3NF:** Eliminates transitive dependencies.
#
# ### **B. Checking Normalization in HMS Database**
#
# * **1NF:**  Passed (No multi-valued attributes).
# * **2NF:**  Passed (All tables use primary keys and avoid partial dependencies).
# * **3NF:**  Passed (No redundant data; only foreign key references).
#
# **Inference:** The database is **fully normalized**, ensuring **optimal performance and minimal redundancy**.
#
# ---
#
#
#
# [image1]: <data:image/png;base64,...>
#
# [image2]: <data:image/png;base64,...>
#
# [image3]: <data:image/png;base64,...>

# %% [markdown]
# ## **Potential Future Impact and Usage**
#
# This hospital management system database, with its detailed structure and comprehensive data storage, lays a strong foundation for significant future impact and diverse usage scenarios beyond basic record-keeping. Here are some potential avenues:
#
# **Enhanced Operational Efficiency:**
#
# * **Predictive Analytics for Resource Allocation:** By analyzing historical data on patient admissions, appointment trends, and resource utilization (rooms, staff, equipment), the system can be leveraged to predict future demands. This allows for proactive allocation of resources, minimizing bottlenecks and improving patient flow. For example, predicting a surge in emergency room visits during specific times of the year could lead to increased staffing during those periods.
# * **Optimized Appointment Scheduling:** Analyzing appointment history, doctor availability, and patient preferences can lead to the development of intelligent scheduling systems. These systems can minimize waiting times, reduce no-shows through automated reminders, and optimize doctor schedules for maximum efficiency.
# * **Streamlined Billing and Insurance Processing:** Integrating the billing and payment data with insurance provider systems can automate claim submissions and processing, reducing administrative overhead and accelerating reimbursement cycles. Identifying patterns in rejected claims can also help in improving the accuracy of future submissions.
# * **Efficient Inventory Management:** Real-time tracking of inventory levels, coupled with predictive analysis of consumption rates, can automate the reordering process for medical supplies and pharmaceuticals. This minimizes stockouts, reduces waste from expired items, and optimizes procurement costs.
#
# **Improved Patient Care and Outcomes:**
#
# * **Personalized Medicine and Treatment Plans:** With a comprehensive history of patient diagnoses, treatments, and test results, the database can be used to identify patterns and correlations that support personalized medicine approaches. Analyzing the effectiveness of different treatments for specific patient profiles can lead to more targeted and successful interventions.
# * **Early Disease Detection and Prevention:** By analyzing patient medical records for risk factors and early indicators of diseases, the system can facilitate proactive screening and preventative care initiatives. For instance, identifying patients with a family history and early symptoms of a particular condition can enable timely intervention.
# * **Enhanced Patient Engagement:** Integrating the database with patient portals can provide patients with secure access to their medical records, appointment schedules, and educational materials. This empowers patients to be more actively involved in their care.
# * **Improved Care Coordination:** The centralized database facilitates seamless information sharing between different departments and healthcare professionals involved in a patient's care. This improves communication, reduces medical errors, and ensures a more coordinated and holistic approach to treatment.
#
# **Research and Development:**
#
# * **Clinical Research and Trials:** Anonymized and aggregated patient data can be invaluable for conducting clinical research, identifying trends in disease prevalence, and evaluating the effectiveness of new treatments and interventions. This can contribute significantly to medical advancements.
# * **Public Health Monitoring and Surveillance:** Aggregated data on diagnoses and disease patterns can be used by public health organizations for monitoring disease outbreaks, identifying at-risk populations, and implementing targeted public health interventions.
# * **Healthcare Policy and Planning:** Analyzing the data on hospital utilization, patient demographics, and treatment outcomes can provide valuable insights for healthcare policy development and resource planning at a regional or national level.
#
# **Potential for Integration:**
#
# * **Integration with External Systems:** The database can be integrated with other healthcare systems, such as electronic health record (EHR) systems used by other providers, external laboratories, and national health information exchanges, to create a more comprehensive and interconnected healthcare ecosystem.
# * **Mobile Applications and Wearable Devices:** Data from mobile health applications and wearable devices can potentially be integrated into the patient records, providing a more continuous and real-time view of a patient's health status.
#
# >**Overall, this hospital management system database is not just a tool for current operations but a valuable asset for driving future improvements in efficiency, patient care, research, and healthcare planning. Its potential will continue to grow as data accumulates and analytical capabilities advance.**

# %% [markdown]
# ## **Conclusion**
#
# The successful development and implementation of this hospital management system database mark a **crucial advancement** in modernizing healthcare administration and optimizing hospital operations. This project involved the **meticulous design** of a robust and well-structured database schema, carefully tailored to address the multifaceted requirements of a contemporary hospital environment. The schema encompasses a wide range of essential functionalities, including:
#
# * **Patient Management:** Centralized storage of comprehensive patient demographics, medical histories, and contact information, facilitating efficient patient tracking and communication.
# * **Doctor and Appointment Scheduling:** Streamlined management of doctor profiles, specializations, and availability, enabling efficient appointment booking, scheduling, and management.
# * **Medical Records Management:** Secure and organized storage of patient medical records, diagnoses, treatments, prescriptions, and test results, ensuring continuity of care and facilitating informed clinical decision-making.
# * **Billing and Payment Management:** Comprehensive tracking of patient billing information, payment transactions, and insurance details, enabling accurate financial management and revenue cycle optimization.
# * **Hospital Staff and Department Management:** Detailed management of hospital staff information, including roles, contact details, department affiliations, and salary information, supporting efficient staff scheduling and resource allocation.
# * **Room and Admission Management:** Effective management of hospital room availability, occupancy status, and patient admission and discharge records, optimizing bed utilization and patient flow.
# * **Inventory and Pharmacy Management:** Real-time tracking of medical supplies, pharmaceuticals, and inventory levels, ensuring timely availability of essential resources and minimizing waste.
# * **Laboratory and Test Management:** Management of diagnostic tests, lab reports, and test results, facilitating efficient laboratory operations and timely delivery of critical information to clinicians.
#
# A cornerstone of this project was the **successful implementation** and **rigorous testing** of all fundamental **CRUD (Create, Read, Update, Delete)** operations across every table within the database. This achievement signifies the system's capacity for effective data management, enabling:
#
# * **Create:** Seamless addition of new records, such as new patient registrations, doctor profiles, appointments, and medical records.
# * **Read:** Efficient retrieval of information, such as patient details, appointment schedules, medical histories, and billing statements.
# * **Update:** Accurate modification of existing data, such as changes to patient contact information, appointment rescheduling, and updates to medical records.
# * **Delete:** Safe and controlled removal of obsolete or irrelevant data, such as discharged patient records or cancelled appointments, while maintaining data integrity.
#
# The successful execution of these CRUD operations **validates** the database's core functionality and its ability to support the essential data management tasks that underpin daily hospital operations.
#
# Beyond basic functionality, the database underwent **comprehensive stress testing** to evaluate its performance and resilience under peak load conditions. These tests simulated realistic high-traffic scenarios, such as:
#
# * Simultaneous patient admissions during a mass casualty event.
# * A surge in appointment bookings during a seasonal flu outbreak.
# * Concurrent access to patient records by multiple clinicians during a shift change.
# * High volumes of billing and payment transactions at the end of the month.
#
# The database's ability to withstand these stress tests and maintain acceptable response times demonstrates its **scalability, stability, and reliability**, which are paramount in a demanding healthcare environment where system downtime can have serious consequences.
#
# Furthermore, the database design adheres to the principles of **normalization**, a critical process that ensures:
#
# * **Data Redundancy Elimination:** Minimizing the duplication of data across multiple tables, reducing storage requirements and preventing inconsistencies.
# * **Data Integrity:** Enforcing data accuracy and consistency through the definition of primary keys, foreign keys, and constraints.
# * **Anomaly Prevention:** Avoiding update, insertion, and deletion anomalies that can compromise data integrity and lead to errors.
#
# By achieving an appropriate normal form, the database exhibits a clear, logical, and efficient structure that facilitates:
#
# * **Efficient Querying:** Faster and more accurate retrieval of information.
# * **Reduced Storage Overhead:** Optimized use of storage resources.
# * **Enhanced Maintainability:** Easier modification and updating of the database schema.
# * **Improved Data Consistency:** Ensuring that data remains accurate and reliable over time.
#
# In conclusion, this hospital management system database represents a **robust, reliable, and scalable** solution for managing critical healthcare data. The successful implementation and testing of CRUD operations, coupled with its proven performance under stress and adherence to normalization principles, establish it as a **valuable asset** for:
#
# * **Streamlining Hospital Operations:** Automating administrative tasks, improving workflow efficiency, and reducing operational costs.
# * **Enhancing Patient Care:** Facilitating seamless access to patient information, improving care coordination, and supporting informed clinical decision-making.
# * **Supporting Healthcare Analytics and Research:** Providing a rich data source for analyzing trends, identifying best practices, and advancing medical knowledge.
#
# This project lays a **strong foundation** for future development and integration with other healthcare systems, ultimately contributing to improved healthcare delivery and patient outcomes.
