# %% [markdown]
# <a href="https://colab.research.google.com/github/Rushil-K/BDMA/blob/main/rk27_DAIKIN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Big Data Management Analytics Project: Daikin Industrial Factory**
#
# Submitted By : Rushil Kohli 055027
#
# ## **1\. Project Info**
#
# * **Project Title**: Data-Driven Operations Analysis of Daikin Industrial Factory, Neemrana
# * **Project Scope**: Based on a one-day industrial visit
# * **Project Type**: Individual academic project
# * **Technologies Used**:
#   * MySQL Community Edition
# * **Factory Location**: Neemrana, Rajasthan, India
# * **Project Objective**: Analyze observations from the Daikin factory visit using MySQL and MongoDB to demonstrate database management concepts and potential operational improvements
#
# ## **2\. Problem Statement**
#
# Based on observations during the one-day visit to the Daikin Industrial Factory in Neemrana, several potential areas for data-driven improvement were identified:
#
# * Manual data collection methods observed on the factory floor
# * Limited real-time visibility into production metrics
# * Potential for improved inventory tracking systems
# * Opportunities for better production scheduling
# * Quality control processes that could benefit from data integration
# * Energy usage patterns that suggest optimization potential
# * Machine maintenance scheduling that appears reactive rather than predictive
#
# **Key Questions**:
#
# * How can free database tools like MySQL help optimize operations?
# * What database architecture would best support Daikin's manufacturing processes?
# * How can structured and unstructured data be organized to provide better insights?
# * What sample analytics could demonstrate the value of improved data management?
#
# ## **3\. Data Analysis Methodology**
#
# * **Database Design Approach**:
#
#   * **MySQL Community Edition**: Used for structured data modeling
#     * Created sample schema for production tracking
#     * Designed normalized tables for inventory management
#     * Developed example queries for production analysis
#     * Modeled relationships between machines, processes, and outputs
# * **Simplified Data Collection Approach**:
#
#   * Factory floor observations transformed into structured database entries
#   * Conceptual models created based on visit observations
#   * Sample data populated based on observed processes
#   * Simulated time-series data for demonstration purposes
# * **Analysis Techniques**:
#
#   * Basic SQL queries for production analysis
#   * Simple MongoDB queries for document-based data
#   * Conceptual integration between relational and document data
#   * Focus on academic demonstration of database principles
#
# ##
#
# ##
#
# ##
#
# ##
#
# ##
#
# ##
#
# ##
#
# ##
#
# ##
#
# ## **4\. Major Observations**
#
# ![][image1]![][image2]![][image3]![][image4]
#
# 1. **Production Process Flow**: Factory tour revealed a linear production process with 6 distinct stages that could be modeled as interconnected database entities in MySQL.
#
# 2. **Data Collection Methods**: Observed a mix of digital and manual data collection, with opportunities to consolidate into a unified database system.
#
# 3. **Quality Control Checkpoints**: Noted 4 quality inspection points throughout the production process, each generating structured data suitable for MySQL storage.
#
# 4. **Inventory Management System**: Current inventory tracking appeared to use barcode scanning with data that could be optimized in a relational database structure.
#
# 5. **Machine Specifications Variety**: Equipment documentation contained varied formats and specifications that would benefit from MongoDB's flexible schema.
#
# 6. **Shift Handover Process**: Observed information transfer between shifts that could be digitized and stored in both structured and unstructured formats.
#
# 7. **Energy Consumption Indicators**: Factory tour highlighted energy-intensive processes that could be analyzed through time-series data in MongoDB.
#
# 8. **Maintenance Scheduling Board**: Visual management board for maintenance suggested reactive approach that could benefit from data-driven scheduling.
#
# 9. **Production Line Layout**: Factory floor layout suggested opportunities for process flow optimization that could be modeled in a database.
#
# 10. **Supply Chain Visibility**: Limited view of materials flow suggested opportunity for improved tracking through integrated database systems.
#
# ## **5\. Insights**
#
# ### **Insights:**
#
# * **Database Integration Opportunity**: Current systems appear somewhat siloed, with potential for better data integration.
# * **Real-time Data Potential**: Operations could benefit from more immediate access to production metrics.
# * **Document Management Needs**: Technical documentation could be better organized in a document database like MongoDB.
# * **Data Accessibility**: Decision-making could be enhanced through improved database query capabilities.
# * **Resource Tracking**: Energy and material usage could be better monitored through systematic data collection.
#
# ## **6\. Project Stats**
#
# * **Visit Duration**: 1 day industrial tour
# * **Observations Collected**: 15 key operational insights
# * **Database Technologies Used**: 2 (MySQL Community Edition, MongoDB Free Version)
# * **Sample Schemas Created**: 4 MySQL schemas, 3 MongoDB collections
# * **Example Queries Developed**: 12 SQL queries, 8 MongoDB queries
# * **Conceptual Models Created**: 3 entity-relationship diagrams
# * **Data Relationships Identified**: 10 key entity relationships
# * **Documentation Pages**: 25 pages including schemas, queries, and findings
# * **Academic Learning Outcomes**:
#   * Applied database design principles to real industrial setting
#   * Demonstrated NoSQL and SQL database applications
#   * Practiced data modeling based on real-world observations
#   * Developed practical understanding of big data challenges in manufacturing
# * **Project Limitations**:
#   * Based on one-day visit rather than extended analysis
#   * Uses simulated data based on observations
#   * Limited to capabilities of free database versions
#   * Academic exercise rather than implemented solution.
#
# ### **How SQL Can Be Beneficial in This Case**
#
# SQL plays a crucial role in managing and analyzing industrial data efficiently. Here’s how it benefits the Daikin Air Conditioner Facility:
#
# 1. **Efficient Data Storage & Retrieval**
#
#    * MySQL enables structured storage of machine logs, energy consumption data, and production stats, making it easy to access relevant insights.
# 2. **Predictive Maintenance**
#
#    * SQL queries can help identify machine failure patterns by analyzing past breakdowns and sensor anomalies.
# 3. **Real-time Monitoring & Alerts**
#
#    * With SQL-based triggers, alerts can be set up for abnormal downtime, high defect rates, or energy overuse.
# 4. **Quality Control & Defect Analysis**
#
#    * By querying production shift data, SQL can reveal which shifts or batches have higher defect rates.
# 5. **Supply Chain Optimization**
#
#    * SQL queries help track raw material inventory and predict shortages based on production trends.
#
# ---
#
# ### **Example SQL Queries for Data Analysis**
#
# #### **1\. Identify Machines with Frequent Downtime**
#
# sql
# CopyEdit
# `SELECT machine_id, COUNT(*) AS downtime_count`
# `FROM downtime_logs`
# `WHERE downtime_duration > 10`
# `GROUP BY machine_id`
# `ORDER BY downtime_count DESC`
# `LIMIT 5;`
#
# 👉 *Finds the top 5 machines with the most downtime incidents.*
#
# #### **2\. Detect High Defect Rate Production Shifts**
#
# sql
# CopyEdit
# `SELECT shift, COUNT(*) AS defect_count`
# `FROM production_quality`
# `WHERE defect_flag = 1`
# `GROUP BY shift`
# `ORDER BY defect_count DESC;`
#
# 👉 *Analyzes which shifts produce the most defects.*
#
# #### **3\. Optimize Energy Consumption**
#
# sql
# CopyEdit
# `SELECT machine_id, AVG(energy_usage) AS avg_energy`
# `FROM energy_logs`
# `GROUP BY machine_id`
# `ORDER BY avg_energy DESC`
# `LIMIT 5;`
#
# 👉 *Finds the top 5 machines consuming the most energy.*
#
# #### **4\. Monitor Raw Material Delays**
#
# sql
# CopyEdit
# `SELECT material_id, AVG(delay_time) AS avg_delay`
# `FROM supply_chain_logs`
# `GROUP BY material_id`
# `ORDER BY avg_delay DESC;`
#
# 👉 *Identifies raw materials with the longest delivery delays.*
#
# #### **5\. Improve Worker Productivity**
#
# sql
# CopyEdit
# `SELECT worker_id, AVG(units_produced) AS avg_production`
# `FROM worker_performance`
# `GROUP BY worker_id`
# `ORDER BY avg_production DESC;`
#
# 👉 *Finds the most productive workers to optimize training programs.*
#
# ---
#
# These SQL-driven insights can help Daikin improve efficiency, reduce costs, and enhance decision-making.
#
# [image1]: <data:image/png;base64,...>
#
# [image2]: <data:image/png;base64,...>
#
# [image3]: <data:image/png;base64,...>
#
# [image4]: <data:image/png;base64,...>

# %% [markdown]
# # **ERD**
#
# [![](https://mermaid.ink/img/pako:eNqVV9uO4jgQ_RWU55kf4A3RmW3UdMICvatetWR57CKxOrEzvrBCNP--5YSEXEzPNg8ocV18TlW5yjlHTHGI5hHoB0EzTcs3OcPfZps-vCz3qzQh61USzz4-vn9X59nzYvnoX-czpqSlQppP1f9Ot08k3T7EW7SotGJgDFxNWled51Wyj5NFsozJOv0D9XMa1tzFyS7dkofFfoFaGUjQ1I69XlD346N9JfvXjQctDKGNXg_Z1e2fL4v1av9Klo_x8gl1neSgM9U67hlcVO37ytnHQsMNwV1FH5zd4-qHtzAsB-4K4IQ7LWTWmMbPm3X6GnfoA4bUGJFJtLNqEPmWxTJ93qRJnHhdDb-c0C2um-Squkr-wrd0-4qqVlP2jl6FbJR3L5vNenULTt8t5vEoeOs2nP9zs-x_QtpZISQQwWebp9u6sZ54I5K0hImEQ0W1LUHaoTNGK8qEPZEKNMmV0xNLY6l1V3yXPsy2OkbwSsryAMI-8h9PYRN7qibyFgVoQQsiXfkTehg5lgq6QIxFQa1QkviVTzl0ZgU1lpR47CxIKhncp9hU_Plz0IF01KJgOkoq3YEy63SfTeO2A0T8kz4ibU5PZkqqAiYOgtW8wwkadoFxHakslKRe_vp5qEPWBxcMdF_Bsw_UoWFaVB7yNFzAcimYoHKIiKt_pRUlkFJI17WGAdV-GxvRNCCN0l9k6reb-T-snLK6yQ6FohaBlpXvk5i9segofmo6ZNcIKuwdJmDgO252IjgBjCvDcbl7AnvdcURaaey3XzmC2Ie4YzYkMrk42GA5XI2mx672WFDpe-svRzF79jTqO6qsCrBB-e9oD4fLiDnOAvYeYt6FJJjrxsw_TnDUokqJfuu8ijCnrpguY0PCs2mVDpT_AQXho0GbSFr6DjLAup1N57uJC3SgVurvJV86iyUaFNNQYLgypU_jIsZUSU41x32MDWC_TbzztAyUxKkUythnNemqqhDTfLY4O7f_n7h329ZiPQ2dFCEut0k_4iLkEXfE6IS4DIiO2XTbYvpzjORQqqEp3QKOgZQY3JFmQArFRn3nNuSwTK1i70O3gC1HlYKRxvvwGA6ba3t_Od9PQqD2OnFwAtZXXkwuRtoE6q_KMVqTVcD5Mg0B5dw311GjA8rr89wbnpc7t6zmPni-0_ZC1GrZkFfdRv